# %% [markdown]
# # Laboratorio 3.1 - Creación e importación de datos
#
# ## Estudiante: Jeisson Andres Villarraga Reyes
#
# ### Importing the data

# %%
# !pip install scipy

import warnings, requests, zipfile, io

warnings.simplefilter('ignore')

import pandas as pd

from scipy.io import arff
# Out:
# ...
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# ...

# %%
f_zip = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00212/vertebral_column_data.zip'

r = requests.get(f_zip, stream=True)

Vertebral_zip = zipfile.ZipFile(io.BytesIO(r.content))

Vertebral_zip.extractall()

# %%
data = arff.loadarff('column_2C_weka.arff')

df = pd.DataFrame(data[0])

df.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis        class
# 0      98.672917                 -0.254400  b'Abnormal'
# 1     114.405425                  4.564259  b'Abnormal'
# 2     105.985135                 -3.530317  b'Abnormal'
# 3     101.868495                 11.211523  b'Abnormal'
# 4     108.168725                  7.918501  b'Abnormal'

# %% [markdown]
# ## Descripción de la actividad
#
# En este laboratorio se trabajó con Amazon SageMaker y JupyterLab. Primero se creó y configuró una instancia de notebook para disponer del entorno necesario para desarrollar la actividad. Posteriormente se exploró JupyterLab y sus diferentes tipos de celdas.
#
# En la parte práctica se creó un notebook con Python, se instalaron e importaron las librerías necesarias y se descargó un conjunto de datos desde una fuente externa. Después se extrajeron los archivos y se cargó el archivo `column_2C_weka.arff` utilizando SciPy y pandas. Finalmente, se convirtió la información en un DataFrame y se utilizó `df.head()` para visualizar los primeros registros.
#
# El propósito de este proceso fue familiarizarse con el uso de SageMaker para trabajar con notebooks y realizar una primera preparación y visualización de datos.
